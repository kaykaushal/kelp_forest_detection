# %%
import os 
import warnings 
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd

import torch 
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import torchvision.transforms as transforms
from pathlib import Path
import numpy as np
import rioxarray as xr

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
## set working direcitory and import project module
HOME_DIR = '/home/jovyan/open_pluto/kelp_forest_detection'
os.chdir(HOME_DIR)
from src.dataset import KelpDataset
from src.model import BaseUnet, UNetPlus, DiceLoss
from src.train import Trainer

# %%
# Set variables and parameters 
TRAIN_DIR = os.path.join(HOME_DIR, 'data/training/')
# Data prams
IMAGE_DIR = os.path.join(TRAIN_DIR,'train_satellite')
MASK_DIR = os.path.join(TRAIN_DIR,'train_kelp')

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
# Model params
WORKER = 2
CHANNEL_IN = 7
CHANNEL_OUT = 1
BATCH_SIZE = 4

# %% [markdown]
# ## Get Data

# %%
# Get metdatafile for training and test split 
meta_df = pd.read_csv('metadata_kelp.csv')
df = meta_df[meta_df['in_train'] == True].head(1000)
train_df, valid_df = train_test_split(df, test_size = .2, random_state=42)
train_files = train_df['filename'].tolist()
valid_files = valid_df['filename'].tolist()
# Check length
len(train_files), len(valid_files)
# Out:
# (800, 200)

# %%
torch.manual_seed(12)
transform = transforms.Compose([
    transforms.ToTensor(),
    #transforms.RandomHorizontalFlip(),
    #transforms.Resize((256, 256)),
    
])
# Custome datasets
# Create a custom training custom dataset for training dataset
train_dataset = KelpDataset(image_dir=IMAGE_DIR, mask_dir=MASK_DIR,
                            transform=transform, filename_list=train_files)
# Create a custom training custom dataset for validation set
valid_dataset = KelpDataset(image_dir=IMAGE_DIR, mask_dir=MASK_DIR,
                            transform=transform, filename_list=valid_files)
# Load dataloader for train and validation set
train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, 
                              num_workers=0, pin_memory=True,  prefetch_factor=2)
# Validation loader
valid_dataloader = DataLoader(valid_dataset, batch_size=BATCH_SIZE, shuffle=False, 
                              num_workers=0, pin_memory=True,  prefetch_factor=WORKER)

# %%
img, mask = next(iter(train_dataloader))
img.shape, mask.shape
# Out:
# (torch.Size([4, 7, 350, 350]), torch.Size([4, 1, 350, 350]))

# %%
plt.imshow(mask[3][0])

# %%
element_at_index_1_0 = mask[3][0]

# Flatten the tensor to a 1D array
flattened_values = element_at_index_1_0.flatten()

# Plot the histogram
plt.hist(flattened_values.numpy(), bins=50, color='blue', alpha=0.7)
plt.title('Distribution / Histogram Chart')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Train Model

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
# Define the objective function for Optuna
def objective(trial):
    # Define hyperparameters to be optimized
    in_channels = 7  # Change if your input channels are different
    out_channels = 1
    features = [trial.suggest_int(f'features_{i}', 32, 512) for i in range(4)]
    dropout_prob = trial.suggest_float('dropout_prob', 0.0, 0.5)
    # Define model
    model = BaseUnet(
        in_channels=in_channels,
        out_channels=out_channels,
        features=features,
        dropout_prob=dropout_prob
    )
    
    # Set training hyperparameter
    lr = trial.suggest_float('lr', 1e-5, 1e-1, log=True)
    # Choose optimizer and its hyperparameters
    optimizer_name = trial.suggest_categorical('optimizer', ['Adam', 'SGD', 'Adamax'])
    weight_decay = trial.suggest_float('weight_decay', 1e-6, 1e-2, log=True)
    if optimizer_name == 'Adam':
        optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    elif optimizer_name == 'SGD':
        momentum = trial.suggest_float('momentum', 0.0, 1.0)
        optimizer = torch.optim.SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=weight_decay)
    else:
        optimizer = torch.optim.Adamax(model.parameters(), lr=lr, weight_decay=weight_decay)

    # Choose loss function
    loss_name = trial.suggest_categorical('loss', ['CrossEntropyLoss', 'DiceLoss'])
    
    if loss_name == 'CrossEntropyLoss':
        criterion = torch.nn.CrossEntropyLoss()
    else:
        # Assuming you have a custom DiceLoss implementation
        criterion = DiceLoss()

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    # Instantiate Trainer with Optuna trial
    trainer = Trainer(
        model=model.to(device),
        train_dataloader=train_dataloader,
        valid_dataloader=valid_dataloader,
        criterion=criterion,
        optimizer=optimizer,
        device=device,
        tb_path='tensorboard/logs/',
        checkpoint_path='models/tune/',
        trial=trial
    )

    # Train the model
    trainer.train(epochs=5)  # Adjust the number of epochs as needed

    # Return a scalar value indicating the performance
    return trainer.best_valid_loss

# %%
import optuna
# Create an optimization study and perform optimization
study = optuna.create_study(direction='minimize')  # Optimize for minimum validation loss
study.optimize(objective, n_trials=10)
# Out:
# [I 2024-01-10 18:55:03,994] A new study created in memory with name: no-name-f97124e2-2856-4167-a8d0-ab8229836941
# Epoch 1/5:   0%|          | 0/200 [00:02<?, ?it/s]
# [W 2024-01-10 18:55:07,160] Trial 0 failed because of the following error: RuntimeError('Given transposed=1, weight of size [154, 77, 2, 2], expected input[4, 439, 43, 43] to have 154 channels, but got 439 channels instead')
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/dist-packages/optuna/study/_optimize.py", line 196, in _run_trial
#     value_or_values = func(trial)
#   File "/tmp/ipykernel_3436/39841380.py", line 54, in objective
#     trainer.train(epochs=5)  # Adjust the number of epochs as needed
#   File "/home/jovyan/open_pluto/kelp_forest_detection/src/train.py", line 56, in train
#     outputs = self.model(data)
#   File "/usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/jovyan/open_pluto/kelp_forest_detection/src/model.py", line 280, in forward
#     x = self.ups[idx](x)
#   File "/usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py", line 1130, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/torch/nn/modules/conv.py", line 950, in forward
#     return F.conv_transpose2d(
# RuntimeError: Given transposed=1, weight of size [154, 77, 2, 2], expected input[4, 439, 43, 43] to have 154 channels, but got 439 channels instead
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [13], line 4
#       2 # Create an optimization study and perform optimization
#       3 study = optuna.create_study(direction='minimize')  # Optimize for minimum validation loss
# ----> 4 study.optimize(objective, n_trials=10)
#
# File /usr/local/lib/python3.8/dist-packages/optuna/study/study.py:419, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     315 def optimize(
#     316     self,
#     317     func: ObjectiveFuncType,
#    (...)
#     324     show_progress_bar: bool = False,
#     325 ) -> None:
#     326     """Optimize an objective function.
#     327
#     328     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     416             If nested invocation of this method occurs.
#     417     """
# --> 419     _optimize(
#     420         study=self,
#     421         func=func,
#     422         n_trials=n_trials,
#     423         timeout=timeout,
#     424         n_jobs=n_jobs,
#     425         catch=catch,
#     426         callbacks=callbacks,
#     427         gc_after_trial=gc_after_trial,
#     428         show_progress_bar=show_progress_bar,
#     429     )
#
# File /usr/local/lib/python3.8/dist-packages/optuna/study/_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if n_jobs == -1:
#
# File /usr/local/lib/python3.8/dist-packages/optuna/study/_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as CircleCI).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File /usr/local/lib/python3.8/dist-packages/optuna/study/_optimize.py:234, in _run_trial(study, func, catch)
#     227         assert False, "Should not reach."
#     229 if (
#     230     frozen_trial.state == TrialState.FAIL
#     231     and func_err is not None
#     232     and not isinstance(func_err, catch)
#     233 ):
# --> 234     raise func_err
#     235 return frozen_trial
#
# File /usr/local/lib/python3.8/dist-packages/optuna/study/_optimize.py:196, in _run_trial(study, func, catch)
#     194 with get_heartbeat_thread(trial._trial_id, study._storage):
#     195     try:
# --> 196         value_or_values = func(trial)
#     197     except exceptions.TrialPruned as e:
#     198         # TODO(mamu): Handle multi-objective cases.
#     199         state = TrialState.PRUNED
#
# Cell In [12], line 54, in objective(trial)
#      41 trainer = Trainer(
#      42     model=model.to(device),
#      43     train_dataloader=train_dataloader,
#    (...)
#      50     trial=trial
#      51 )
#      53 # Train the model
# ---> 54 trainer.train(epochs=5)  # Adjust the number of epochs as needed
#      56 # Return a scalar value indicating the performance
#      57 return trainer.best_valid_loss
#
# File ~/open_pluto/kelp_forest_detection/src/train.py:56, in Trainer.train(self, epochs)
#      54 # foward
#      55 self.optimizer.zero_grad()
# ---> 56 outputs = self.model(data)
#      57 loss = self.criterion(outputs, targets)
#      58 dice_coefficient = calculate_dice_coefficient(torch.sigmoid(outputs) > 0.5,
#      59                                                   targets > 0.5)
#
# File /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/open_pluto/kelp_forest_detection/src/model.py:280, in UNetPlus.forward(self, x)
#     277 skip_connections = skip_connections[::-1]
#     279 for idx in range(0, len(self.ups), 2):
# --> 280     x = self.ups[idx](x)
#     281     skip_connection = skip_connections[idx//2]
#     283     if x.shape != skip_connection.shape:
#
# File /usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/lib/python3.8/dist-packages/torch/nn/modules/conv.py:950, in ConvTranspose2d.forward(self, input, output_size)
#     945 num_spatial_dims = 2
#     946 output_padding = self._output_padding(
#     947     input, output_size, self.stride, self.padding, self.kernel_size,  # type: ignore[arg-type]
#     948     num_spatial_dims, self.dilation)  # type: ignore[arg-type]
# --> 950 return F.conv_transpose2d(
#     951     input, self.weight, self.bias, self.stride, self.padding,
#     952     output_padding, self.groups, self.dilation)
#
# RuntimeError: Given transposed=1, weight of size [154, 77, 2, 2], expected input[4, 439, 43, 43] to have 154 channels, but got 439 channels instead
